# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
clg10=np.genfromtxt("output/test_g1.0cl.dat")
clg11=np.genfromtxt("output/test_g1.1cl.dat")

# %%
clg10.shape
# Out:
# (2499, 5)

# %%
plt.plot(clg10[:,1],label)
plt.plot(clg11[:,1])
